# %%
# !pip install pandas
# !pip install numpy
# !pip install seaborn
# !pip install matplotlib

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
d = sns.load_dataset('titanic')
d.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
d.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.histplot(titanic['fare'], bins=10)
plt.xlabel('Fare')
plt.ylabel('Count')
plt.title("Distribution of Ticket Fare")
plt.show()

# %%
sns.boxplot(x='pclass', y='fare', data=titanic)
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
plt.title("Ticket Fare by Passenger Class")
plt.show()

# %%
sns.violinplot(x='embarked', y='fare', data=titanic)
plt.xlabel('Embarked Port')
plt.ylabel('Fare')
plt.title("Ticket Fare by Embarked Port")
plt.show()

# %%
sns.jointplot(x='age', y='fare', data=titanic)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
sns.swarmplot(x='sex', y='age', data=titanic)
plt.title("Swarm Plot of Age by Gender")
plt.show()

# %%
sns.stripplot(x='sex', y='age', data=d)
plt.title("Strip Plot of Age by Gender")
plt.show()

# %%
sns.countplot(x='sex', data=d)
plt.title("Male and Female Passengers Count")
plt.show()

# %%
sns.histplot(d['age'], bins=10)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title("Age Distribution of Passengers")
plt.show()

# %%
sns.rugplot(d['fare'])
plt.title("Rug Plot of Ticket Fare")
plt.show()

# %%
corr = d.select_dtypes(include=np.number).corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
corr = d.select_dtypes(include=np.number).corr()
sns.clustermap(corr, annot=True, cmap='coolwarm')
plt.title("Cluster Map of Correlation between Features")
# Out:
# Text(0.5, 1.0, 'Cluster Map of Correlation between Features')
